# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/ETH-USD.csv')
df_large = pd.read_csv('../data/ETH-USD_large.csv')

# %%
plt.figure(figsize=(16, 8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Price')
plt.plot(df_large['Close'])
plt.show()
